# %% [markdown]
# Testing display function of pillow library

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'white')
draw = ImageDraw.Draw(image)

headerheight = 20
footerheight = 20
mainheight = 320 - headerheight - footerheight

headerfont = ImageFont.truetype('Menlo-Regular.ttf', headerheight-4)
footerfont = ImageFont.truetype('Menlo-Regular.ttf', footerheight-4)

# red header
draw.rectangle((0, 0, 480, headerheight), fill='red')
# home icon
draw.rectangle((4, 4, 15, 15), fill='white')
draw.text((20, 1), 'PaginaNaam', fill='white', font=headerfont) 

# blue main
draw.rectangle((0, headerheight, 480, 320 - footerheight), fill='blue')

# green footer
draw.rectangle((0, 320 - footerheight, 480, 320), fill='green')

# footer current
draw.rectangle((4, 320 - footerheight + 4, 15, 320 - footerheight + 15), fill='white')
draw.text((20, 320 - footerheight + 1), '1.00A > 1.00A', fill='white', font=footerfont)

# footer material (ofset 160)
draw.rectangle((160 + 4, 320 - footerheight + 4, 160 + 15, 320 - footerheight + 15), fill='white')
draw.text((160 + 20, 320 - footerheight + 1), 'Copper', fill='white', font=footerfont)

# rotation speed (ofset 160)
draw.rectangle((320 + 4, 320 - footerheight + 4, 320 + 15, 320 - footerheight + 15), fill='white')
draw.text((320 + 20, 320 - footerheight + 1), 'On', fill='white', font=footerfont)

# rotation speed 2 (ofset 260)
draw.rectangle((260 + 4, 320 - footerheight + 4, 260 + 15, 320 - footerheight + 15), fill='white')
draw.text((260 + 20, 320 - footerheight + 1), 'On', fill='white', font=footerfont)



# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %% [markdown]
# # Home screen

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'white')
draw = ImageDraw.Draw(image)

headerheight = 20
footerheight = 20
mainheight = 320 - headerheight - footerheight

headerfont = ImageFont.truetype('Menlo-Regular.ttf', headerheight-4)
footerfont = ImageFont.truetype('Menlo-Regular.ttf', footerheight-4)
titlefont = ImageFont.truetype('Menlo-Regular.ttf', 30)

# red header
draw.rectangle((0, 0, 480, headerheight), fill='white')
# home icon
draw.rectangle((4, 4, 15, 15), fill='black')
draw.text((20, 1), 'Home', fill='black', font=headerfont) 

# blue main
draw.rectangle((0, headerheight, 480, 320 - footerheight), fill='white')
draw.text((175, 20), 'G L I M', fill='black', font=titlefont)

# four buttons 2 x 2
buttonwidth = (480 - 60) / 2
buttonheight = (mainheight - 60) / 2
draw.rectangle((25, 60, 25 + buttonwidth, 60 + buttonheight), fill='#61A8A7', outline='black', width=2)
draw.text((25 + 10, 60 + buttonheight - 20), 'Plate with file', fill='white', font=footerfont)

draw.rectangle((25, 60 + buttonheight + 10, 25 + buttonwidth, 60 + buttonheight + buttonheight + 10), fill='gray', outline='black', width=2)
draw.text((25 + 10, 60 + buttonheight + 10 + buttonheight - 20), 'Setings', fill='white', font=footerfont)

draw.rectangle((25 + buttonwidth + 10, 60, 25 + buttonwidth + buttonwidth + 10, 60 + buttonheight), fill='gray', outline='black', width=2)
draw.text((25 + buttonwidth + 10 + 10, 60 + buttonheight - 20), 'Plate without file', fill='white', font=footerfont)

draw.rectangle((25 + buttonwidth + 10, 60 + buttonheight + 10, 25 + buttonwidth + buttonwidth + 10, 60 + buttonheight + buttonheight + 10), fill='gray', outline='black', width=2)
draw.text((25 + buttonwidth + 10 + 10, 60 + buttonheight + 10 + buttonheight - 20), 'Tools', fill='white', font=footerfont)


# green footer
draw.rectangle((0, 320 - footerheight, 480, 320), fill='white')

# footer current
draw.rectangle((4, 320 - footerheight + 4, 15, 320 - footerheight + 15), fill='black')
draw.text((20, 320 - footerheight + 1), '1.00A > 1.00A', fill='black', font=footerfont)

# footer material (ofset 160)
draw.rectangle((160 + 4, 320 - footerheight + 4, 160 + 15, 320 - footerheight + 15), fill='black')
draw.text((160 + 20, 320 - footerheight + 1), 'Copper', fill='black', font=footerfont)

# rotation speed (ofset 160)
draw.rectangle((320 + 4, 320 - footerheight + 4, 320 + 15, 320 - footerheight + 15), fill='black')
draw.text((320 + 20, 320 - footerheight + 1), 'On', fill='black', font=footerfont)

# rotation speed 2 (ofset 260)
draw.rectangle((260 + 4, 320 - footerheight + 4, 260 + 15, 320 - footerheight + 15), fill='black')
draw.text((260 + 20, 320 - footerheight + 1), 'On', fill='black', font=footerfont)



# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import PIL.ImageFont

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'black')
draw = ImageDraw.Draw(image)

BackgroundColor = '#FFFFFF'
TextColor = '#000000'
HighlightColor = '#E56F39'
TintedBackgroundColor = '#F0C0A0'

if False:
    # Dark mode
    BackgroundColor = '#000000'
    TextColor = '#FFFFFF'
    HighlightColor = '#E56F39'


def drawHomeScreen(draw:ImageDraw.Draw, menuPos):
    titleFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 40)
    buttonFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 20)
    footerFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)

    # Background
    draw.rectangle((0, 0, 480, 320), fill=BackgroundColor)

    # Title block: Height 60, Text: G L I M, centered
    draw.text((155, 10), 'G L I M', fill=HighlightColor, font=titleFont)
    
    # button block: Height 200, 2 x 2, Width 480
    # margin 10
    # button width = 210
    # button height = 95

    buttons = [
        ('ImportFileIcon.png', 'Import', 'File'),
        ('WithoutFileIcon.png', 'Without', 'File'),
        ('Settings.png', 'Settings', ''),
        ('Tools.png', 'Tools', '')
    ]


    for x in range(2):
        for y in range(2):
            totalPaddingX = 25 + 10 * (x)
            totalPaddingY = 10 * (y)

            draw.rounded_rectangle((
                x * 210 + totalPaddingX, 
                60 + y * 95 + totalPaddingY, 
                (x + 1) * 210 + totalPaddingX, 
                60 + (y + 1) * 95 + totalPaddingY
            ), 10, 
                fill= TintedBackgroundColor, #HighlightColor if menuPos == x + y * 3 else TintedBackgroundColor,
                outline= HighlightColor if menuPos == x + y * 3 else TextColor, width=5 if menuPos == x + y * 3 else 2
            )

            # import icon from file
            icon = Image.open(f'icons/{buttons[x + y * 2][0]}')
            icon = icon.resize((100, 100))
            # make icon transparent
            icon = icon.convert('RGBA')
            r, g, b, a = icon.split()
            # Make black pixels transparent
            a = a.point(lambda p: 0 if p == 0 else 255)

            icon.putalpha(a)

            image.paste(icon, (x * 210 + totalPaddingX, 60 + y * 95 + totalPaddingY), icon)

            # text of button, directly next to icon
            draw.text((x * 210 + totalPaddingX + 100, 60 + y * 95 + totalPaddingY + 20), buttons[x + y * 2][1], fill=TextColor, font=buttonFont)
            draw.text((x * 210 + totalPaddingX + 100, 60 + y * 95 + totalPaddingY + 50), buttons[x + y * 2][2], fill=TextColor, font=buttonFont)


            
    # Footer block: Height 60
    icon = Image.open(f'icons/lightning.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    a = a.point(lambda p: 0 if p == 0 else 255)
    icon.putalpha(a)
    image.paste(icon, (0, 270), icon)

    draw.text((40, 286), f'{0.1234:.2f}A > {0.1234:.2f}A', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/material.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    a = a.point(lambda p: 0 if p == 0 else 255)
    icon.putalpha(a)
    image.paste(icon, (170, 270), icon)

    draw.text((220, 286), 'Copper', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/rotateModel.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    a = a.point(lambda p: 0 if p == 0 else 255)
    icon.putalpha(a)

    image.paste(icon, (280, 270), icon)

    draw.text((325, 286), 'OFF', fill=TextColor, font=footerFont)


    icon = Image.open(f'icons/rotateBean.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    a = a.point(lambda p: 0 if p == 0 else 255)
    icon.putalpha(a)

    image.paste(icon, (360, 270), icon)

    draw.text((405, 286), 'OFF', fill=TextColor, font=footerFont)
            

drawHomeScreen(draw, 0)

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import PIL.ImageFont

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'black')
draw = ImageDraw.Draw(image)

BackgroundColor = '#FFFFFF'
TextColor = '#000000'
SelectedTextColor = '#FFFFFF'
HighlightColor = '#E56F39'
TintedBackgroundColor = '#F0C0A0'
NotSelectedColor = '#FAE5E0'

if False:
    # Dark mode
    BackgroundColor = '#000000'
    TextColor = '#FFFFFF'
    HighlightColor = '#E56F39'


def drawHomeScreen(draw:ImageDraw.Draw, menuPos):
    titleFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 40)
    buttonFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 20)
    footerFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)

    # Background
    draw.rectangle((0, 0, 480, 320), fill=BackgroundColor)

    # Title block: Height 60, Text: G L I M, centered
    draw.text((155, 10), 'G L I M', fill=HighlightColor, font=titleFont)
    
    # button block: Height 200, 2 x 2, Width 480
    # margin 10
    # button width = 210
    # button height = 95

    buttons = [
        ('ImportFileIcon.png', 'Import', 'File'),
        ('WithoutFileIcon.png', 'Without', 'File'),
        ('Settings.png', 'Settings', ''),
        ('Tools.png', 'Tools', '')
    ]


    for x in range(2):
        for y in range(2):
            totalPaddingX = 25 + 10 * (x)
            totalPaddingY = 10 * (y)

            draw.rounded_rectangle((
                x * 210 + totalPaddingX, 
                60 + y * 95 + totalPaddingY, 
                (x + 1) * 210 + totalPaddingX, 
                60 + (y + 1) * 95 + totalPaddingY
            ), 10, 
                fill= TintedBackgroundColor if menuPos == x + y * 3 else NotSelectedColor,
                outline= HighlightColor if menuPos == x + y * 3 else TextColor, width=5 if menuPos == x + y * 3 else 2
            )

            # import icon from file
            icon = Image.open(f'icons/{buttons[x + y * 2][0]}')
            icon = icon.resize((100, 100))
            # make icon transparent
            icon = icon.convert('RGBA')

            # if not (menuPos == x + y * 3):
            #     # replace white with black
            #     r = r.point(lambda p: 0 if p == 255 else p)
            #     g = g.point(lambda p: 0 if p == 255 else p)
            #     b = b.point(lambda p: 0 if p == 255 else p)

            for i in range(icon.width):
                for j in range(icon.height):
                    pixel = icon.getpixel((i, j))
                    
                    if pixel[3] > 0:  # Check if the pixel is not transparent

                        if not (menuPos == x + y * 3):
                            # replace white with black
                            if pixel[0] > 200 and pixel[1] > 200 and pixel[2] > 200:
                                pixel = (0, 0, 0, pixel[3])

                        draw.point((x * 210 + totalPaddingX + i, 60 + y * 95 + totalPaddingY + j), fill=(pixel[0], pixel[1], pixel[2]))

            

            # image.paste(icon, (x * 210 + totalPaddingX, 60 + y * 95 + totalPaddingY), icon)

            # text of button, directly next to icon
            draw.text((x * 210 + totalPaddingX + 100, 60 + y * 95 + totalPaddingY + 20), buttons[x + y * 2][1], fill=SelectedTextColor if menuPos == x + y * 3 else TextColor, font=buttonFont)
            draw.text((x * 210 + totalPaddingX + 100, 60 + y * 95 + totalPaddingY + 50), buttons[x + y * 2][2], fill=SelectedTextColor if menuPos == x + y * 3 else TextColor, font=buttonFont)


            
    # Footer block: Height 60
    icon = Image.open(f'icons/Lightning.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    draw.bitmap((0, 270), icon, fill=HighlightColor)

    draw.text((40, 286), f'{0.1234:.2f}A > {0.1234:.2f}A', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/Material.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((170, 270), icon, fill=HighlightColor)

    draw.text((220, 286), 'Copper', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/RotateModel.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((280, 270), icon, fill=HighlightColor)

    draw.text((325, 286), 'OFF', fill=TextColor, font=footerFont)


    icon = Image.open(f'icons/RotateBean.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((360, 270), icon, fill=HighlightColor)

    draw.text((405, 286), 'OFF', fill=TextColor, font=footerFont)
            

drawHomeScreen(draw, 0)

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import PIL.ImageFont

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'black')
draw = ImageDraw.Draw(image)

BackgroundColor = '#FFFFFF'
TextColor = '#000000'
SelectedTextColor = '#FFFFFF'
HighlightColor = '#E56F39'
TintedBackgroundColor = '#F0C0A0'
NotSelectedColor = '#FAE5E0'

if False:
    # Dark mode
    BackgroundColor = '#000000'
    TextColor = '#FFFFFF'
    HighlightColor = '#E56F39'


def drawFileImportScreen(draw:ImageDraw.Draw, menuPos):
    titleFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 40)
    buttonFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)
    footerFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)

    # Background
    draw.rectangle((0, 0, 480, 320), fill=BackgroundColor)

    # Title block: Height 24
    # back button
    icon = Image.open(f'icons/BackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((4, 4), icon, fill=HighlightColor)
    draw.text((20, 3), 'Select file', fill=HighlightColor, font=buttonFont)
    
    # button block: Height 236, 2 x 2, Width 480
    # margin 10
    # button width = 210
    # button height = 95

    # list of files with file1.stl, file2.stl, file3.stl, file4.stl, ect.
    files = [f"file{i}.stl" for i in range(1, 10)]

    startFileIndex = menuPos - 1 if menuPos > 0 else 0

    # show 5 files
    for i in range(5):
        if startFileIndex + i < len(files):
            draw.rounded_rectangle((
                20, 
                24 + i * 51, 
                370, 
                24 + (i + 1) * 51 - 5
            ), 10, 
                fill= TintedBackgroundColor if menuPos == i + 1 else NotSelectedColor,
                outline= HighlightColor if menuPos == i + 1 else TextColor, width=5 if menuPos == i + 1 else 2
            )

            draw.text((30, 24 + i * 51 + 15), files[startFileIndex + i], fill=SelectedTextColor if menuPos == i + 1 else TextColor, font=buttonFont)

    # up button
    draw.ellipse((
        390,
        35,
        460,
        35 + 70
    ), fill=NotSelectedColor, outline=TextColor, width=2)
    icon = Image.open(f'icons/UpButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41), icon, fill="black")

    # down button
    draw.ellipse((
        390,
        35 + 80,
        460,
        35 + 150
    ), fill=NotSelectedColor, outline=TextColor, width=2)
    icon = Image.open(f'icons/DownButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41 + 80), icon, fill="black")

    # back button
    draw.ellipse((
        390,
        35 + 160,
        460,
        35 + 230
    ), fill=TintedBackgroundColor if menuPos == 0 else NotSelectedColor, outline=HighlightColor if menuPos == 0 else TextColor, width=4)
    icon = Image.open(f'icons/BigBackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((398, 41 + 160), icon, fill="black")

    
            
    # Footer block: Height 60
    icon = Image.open(f'icons/Lightning.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    draw.bitmap((0, 270), icon, fill=HighlightColor)

    draw.text((38, 286), f'{0.1234:.2f}A > {0.1234:.2f}A', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/Material.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((170, 270), icon, fill=HighlightColor)

    draw.text((220, 286), 'Copper', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/RotateModel.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((280, 270), icon, fill=HighlightColor)

    draw.text((325, 286), 'OFF', fill=TextColor, font=footerFont)


    icon = Image.open(f'icons/RotateBean.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((360, 270), icon, fill=HighlightColor)

    draw.text((405, 286), 'OFF', fill=TextColor, font=footerFont)
            

drawFileImportScreen(draw, 0)

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import PIL.ImageFont

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'black')
draw = ImageDraw.Draw(image)

BackgroundColor = '#FFFFFF'
TextColor = '#000000'
SelectedTextColor = '#FFFFFF'
HighlightColor = '#E56F39'
TintedBackgroundColor = '#F0C0A0'
NotSelectedColor = '#FAE5E0'

if False:
    # Dark mode
    BackgroundColor = '#000000'
    TextColor = '#FFFFFF'
    HighlightColor = '#E56F39'


def drawPlateScreen(draw:ImageDraw.Draw, menuPos):
    titleFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 40)
    buttonFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)
    footerFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)

    # Background
    draw.rectangle((0, 0, 480, 320), fill=BackgroundColor)

    # Title block: Height 24
    # back button
    icon = Image.open(f'icons/BackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((4, 4), icon, fill=HighlightColor)
    draw.text((20, 3), 'Plate', fill=HighlightColor, font=buttonFont)
    
    # button block: Height 236, 2 x 2, Width 480
    # margin 10
    # button width = 210
    # button height = 95

    # list of files with file1.stl, file2.stl, file3.stl, file4.stl, ect.
    files = [f"file{i}.stl" for i in range(1, 10)]

    startFileIndex = menuPos - 1 if menuPos > 0 else 0

    # Show current file name
    draw.text((20, 30), 'SuperCoolFileName.stl', fill=TextColor, font=buttonFont)

    # Show some data
    draw.text((20, 60), 'Area:', fill=TextColor, font=buttonFont)
    draw.text((140, 60), 'Time left:', fill=TextColor, font=buttonFont)
    draw.text((260, 60), 'Thickness:', fill=TextColor, font=buttonFont)

    draw.text((20, 80), '123.45 cm2', fill=TextColor, font=buttonFont)
    draw.text((140, 80), '1:23:45', fill=TextColor, font=buttonFont)
    draw.text((260, 80), '1.23 mm', fill=TextColor, font=buttonFont)

    # Progress bar
    draw.rectangle((20, 120, 380, 140), fill=TintedBackgroundColor)
    persent = 0.38
    draw.rectangle((20, 120, 20 + 360 * persent, 140), fill=HighlightColor)
    draw.rectangle((20, 120, 380, 140), outline=TextColor, width=2)

    draw.text((20, 150), f"{persent*100:.0f}%", fill=TextColor, font=titleFont)

    
    # tune button
    draw.ellipse((
        390,
        35,
        460,
        35 + 70
    ), fill=NotSelectedColor, outline=TextColor, width=2)
    icon = Image.open(f'icons/Settings.png')
    icon = icon.resize((75, 75))
    icon = icon.convert('RGBA')
    draw.bitmap((389, 34), icon, fill="black")

    # Pause button
    draw.ellipse((
        390,
        35 + 80,
        460,
        35 + 150
    ), fill=NotSelectedColor, outline=TextColor, width=2)
    icon = Image.open(f'icons/PauseButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41 + 80), icon, fill="black")

    # Stop button
    draw.ellipse((
        390,
        35 + 160,
        460,
        35 + 230
    ), fill=TintedBackgroundColor if menuPos == 0 else NotSelectedColor, outline=HighlightColor if menuPos == 0 else TextColor, width=4)
    icon = Image.open(f'icons/CrossButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41 + 160), icon, fill="black")

    
            
    # Footer block: Height 60
    icon = Image.open(f'icons/Lightning.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    draw.bitmap((0, 270), icon, fill=HighlightColor)

    draw.text((38, 286), f'{0.1234:.2f}A > {0.1234:.2f}A', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/Material.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((170, 270), icon, fill=HighlightColor)

    draw.text((220, 286), 'Copper', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/RotateModel.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((280, 270), icon, fill=HighlightColor)

    draw.text((325, 286), 'OFF', fill=TextColor, font=footerFont)


    icon = Image.open(f'icons/RotateBean.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((360, 270), icon, fill=HighlightColor)

    draw.text((405, 286), 'OFF', fill=TextColor, font=footerFont)
            

drawPlateScreen(draw, 0)

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import PIL.ImageFont

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'black')
draw = ImageDraw.Draw(image)

BackgroundColor = '#FFFFFF'
TextColor = '#000000'
SelectedTextColor = '#FFFFFF'
HighlightColor = '#E56F39'
TintedBackgroundColor = '#F0C0A0'
NotSelectedColor = '#FAE5E0'

if False:
    # Dark mode
    BackgroundColor = '#000000'
    TextColor = '#FFFFFF'
    HighlightColor = '#E56F39'


def drawPlateWithoutFileScreen(draw:ImageDraw.Draw, menuPos):
    titleFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 40)
    buttonFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 25)
    footerFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)

    # Background
    draw.rectangle((0, 0, 480, 320), fill=BackgroundColor)

    # Title block: Height 24
    # back button
    icon = Image.open(f'icons/BackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((4, 4), icon, fill=HighlightColor)
    draw.text((20, 3), 'Plate without file', fill=HighlightColor, font=footerFont)
    
    # button block: Height 236, 2 x 2, Width 480
    # margin 10
    # button width = 210
    # button height = 95

    # area, thickness, groundmaterial, ect.
    draw.text((20, 40), 'Area:', fill=TextColor, font=buttonFont)
    draw.text((100, 40), '123.45 dm²', fill=TextColor, font=buttonFont)

    draw.text((20, 80), 'Thickness:', fill=TextColor, font=buttonFont)
    draw.text((170, 80), '1.23 mm', fill=TextColor, font=buttonFont)

    draw.text((20, 120), 'Rotation:', fill=TextColor, font=buttonFont)
    draw.text((160, 120), 'OFF', fill=TextColor, font=buttonFont)



    
    # up button
    draw.ellipse((
        390,
        35,
        460,
        35 + 70
    ), fill=NotSelectedColor, outline=TextColor, width=2)
    icon = Image.open(f'icons/UpButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41), icon, fill="black")

    # down button
    draw.ellipse((
        390,
        35 + 80,
        460,
        35 + 150
    ), fill=NotSelectedColor, outline=TextColor, width=2)

    icon = Image.open(f'icons/DownButton.png')
    icon = Image.open(f'icons/CheckButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41 + 80), icon, fill="black")

    # back button
    draw.ellipse((
        390,
        35 + 160,
        460,
        35 + 230
    ), fill=TintedBackgroundColor if menuPos == 0 else NotSelectedColor, outline=HighlightColor if menuPos == 0 else TextColor, width=4)
    icon = Image.open(f'icons/BigBackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((398, 41 + 160), icon, fill="black")


    # Footer block: Height 60
    icon = Image.open(f'icons/Lightning.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    draw.bitmap((0, 270), icon, fill=HighlightColor)

    draw.text((38, 286), f'{0.1234:.2f}A > {0.1234:.2f}A', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/Material.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((170, 270), icon, fill=HighlightColor)

    draw.text((220, 286), 'Copper', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/RotateModel.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((280, 270), icon, fill=HighlightColor)

    draw.text((325, 286), 'OFF', fill=TextColor, font=footerFont)


    icon = Image.open(f'icons/RotateBean.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((360, 270), icon, fill=HighlightColor)

    draw.text((405, 286), 'OFF', fill=TextColor, font=footerFont)
            

drawPlateWithoutFileScreen(draw, 0)

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import PIL.ImageFont

# Create a new image with white background
image = Image.new('RGB', (480, 320), 'black')
draw = ImageDraw.Draw(image)

BackgroundColor = '#FFFFFF'
TextColor = '#000000'
SelectedTextColor = '#FFFFFF'
HighlightColor = '#E56F39'
TintedBackgroundColor = '#F0C0A0'
NotSelectedColor = '#FAE5E0'

if False:
    # Dark mode
    BackgroundColor = '#000000'
    TextColor = '#FFFFFF'
    HighlightColor = '#E56F39'


def drawToolsScreen(draw:ImageDraw.Draw, menuPos):
    titleFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 40)
    buttonFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)
    footerFont = PIL.ImageFont.truetype('Menlo-Regular.ttf', 15)

    # Background
    draw.rectangle((0, 0, 480, 320), fill=BackgroundColor)

    # Title block: Height 24
    # back button
    icon = Image.open(f'icons/BackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((4, 4), icon, fill=HighlightColor)
    draw.text((20, 3), 'Plate without file', fill=HighlightColor, font=footerFont)
    
    # button block: Height 236, 2 x 2, Width 480
    # margin 10
    # button width = 210
    # button height = 95

    buttons = [
        ('ImportFileIcon.png', 'Rotate model', 'File'),
        ('WithoutFileIcon.png', 'Rotate bean', 'File'),
        ('Settings.png', 'Lights', ''),
        ('Tools.png', 'Selftest', ''),
        ('ImportFileIcon.png', 'Bath health', 'File'),
        ('WithoutFileIcon.png', 'Remove', 'crystals'),
        ('Settings.png', 'Settings', ''),
        ('Tools.png', 'Tools', '')
    ]


    for x in range(2):
        for y in range(4):
            totalPaddingX = 10 + 10 * (x)
            totalPaddingY = 10 + 10 * (y)

            draw.rounded_rectangle((
                x * 180 + totalPaddingX, 
                20 + y * 50 + totalPaddingY, 
                (x + 1) * 180 + totalPaddingX, 
                20 + (y + 1) * 50 + totalPaddingY
            ), 10, 
                fill= TintedBackgroundColor if menuPos == x + y * 3 else NotSelectedColor,
                outline= HighlightColor if menuPos == x + y * 3 else TextColor, width=5 if menuPos == x + y * 3 else 2
            )

            # import icon from file
            icon = Image.open(f'icons/{buttons[x + y * 2][0]}')
            icon = icon.resize((50, 50))
            # make icon transparent
            icon = icon.convert('RGBA')

            # if not (menuPos == x + y * 3):
            #     # replace white with black
            #     r = r.point(lambda p: 0 if p == 255 else p)
            #     g = g.point(lambda p: 0 if p == 255 else p)
            #     b = b.point(lambda p: 0 if p == 255 else p)

            for i in range(icon.width):
                for j in range(icon.height):
                    pixel = icon.getpixel((i, j))
                    
                    if pixel[3] > 0:  # Check if the pixel is not transparent

                        if not (menuPos == x + y * 3):
                            # replace white with black
                            if pixel[0] > 200 and pixel[1] > 200 and pixel[2] > 200:
                                pixel = (0, 0, 0, pixel[3])

                        draw.point((x * 180 + totalPaddingX + i, 22 + y * 50 + totalPaddingY + j), fill=(pixel[0], pixel[1], pixel[2]))

            

            # image.paste(icon, (x * 210 + totalPaddingX, 60 + y * 95 + totalPaddingY), icon)

            # text of button, directly next to icon
            draw.text((x * 180 + totalPaddingX + 50, 12 + y * 50 + totalPaddingY + 15), buttons[x + y * 2][1], fill=SelectedTextColor if menuPos == x + y * 3 else TextColor, font=buttonFont)
            draw.text((x * 180 + totalPaddingX + 50, 12 + y * 50 + totalPaddingY + 35), buttons[x + y * 2][2], fill=SelectedTextColor if menuPos == x + y * 3 else TextColor, font=buttonFont)
        

    
    # up button
    draw.ellipse((
        390,
        35,
        460,
        35 + 70
    ), fill=NotSelectedColor, outline=TextColor, width=2)
    icon = Image.open(f'icons/UpButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41), icon, fill="black")

    # down button
    draw.ellipse((
        390,
        35 + 80,
        460,
        35 + 150
    ), fill=NotSelectedColor, outline=TextColor, width=2)

    icon = Image.open(f'icons/DownButton.png')
    icon = Image.open(f'icons/CheckButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((396, 41 + 80), icon, fill="black")

    # back button
    draw.ellipse((
        390,
        35 + 160,
        460,
        35 + 230
    ), fill=TintedBackgroundColor if menuPos == 0 else NotSelectedColor, outline=HighlightColor if menuPos == 0 else TextColor, width=4)
    icon = Image.open(f'icons/BigBackButton.png')
    icon = icon.convert('RGBA')
    draw.bitmap((398, 41 + 160), icon, fill="black")


    # Footer block: Height 60
    icon = Image.open(f'icons/Lightning.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    r, g, b, a = icon.split()
    draw.bitmap((0, 270), icon, fill=HighlightColor)

    draw.text((38, 286), f'{0.1234:.2f}A > {0.1234:.2f}A', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/Material.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((170, 270), icon, fill=HighlightColor)

    draw.text((220, 286), 'Copper', fill=TextColor, font=footerFont)

    icon = Image.open(f'icons/RotateModel.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((280, 270), icon, fill=HighlightColor)

    draw.text((325, 286), 'OFF', fill=TextColor, font=footerFont)


    icon = Image.open(f'icons/RotateBean.png')
    icon = icon.resize((50, 50))
    icon = icon.convert('RGBA')
    draw.bitmap((360, 270), icon, fill=HighlightColor)

    draw.text((405, 286), 'OFF', fill=TextColor, font=footerFont)
            

drawToolsScreen(draw, 0)

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>
